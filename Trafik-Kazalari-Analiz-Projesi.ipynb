# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
df = pd.read_csv("accidents_2012_to_2014.csv")
df.head()
# Out:
#   Accident_Index  Location_Easting_OSGR  Location_Northing_OSGR  Longitude  \
# 0  201201BS70001                 527200                  178760  -0.169101
# 1  201201BS70002                 524930                  181430  -0.200838
# 2  201201BS70003                 525860                  178080  -0.188636
# 3  201201BS70004                 524980                  181030  -0.200259
# 4  201201BS70005                 526170                  179200  -0.183773
#
#     Latitude  Police_Force  Accident_Severity  Number_of_Vehicles  \
# 0  51.493429             1                  3                   2
# 1  51.517931             1                  3                   2
# 2  51.487618             1                  3                   2
# 3  51.514325             1                  3                   1
# 4  51.497614             1                  3                   1
#
#    Number_of_Casualties        Date  ...  \
# 0                     1  19/01/2012  ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 207208 entries, 0 to 207207
# Data columns (total 33 columns):
#  #   Column                                       Non-Null Count   Dtype
# ---  ------                                       --------------   -----
#  0   Accident_Index                               207208 non-null  object
#  1   Location_Easting_OSGR                        207208 non-null  int64
#  2   Location_Northing_OSGR                       207208 non-null  int64
#  3   Longitude                                    207208 non-null  float64
#  4   Latitude                                     207208 non-null  float64
#  5   Police_Force                                 207208 non-null  int64
#  6   Accident_Severity                            207208 non-null  int64
#  7   Number_of_Vehicles                           207208 non-null  int64
#  8   Number_of_Casualties                         207208 non-null  int64
# ...

# %%
df.describe().T
# Out:
#                                count           mean            std  \
# Location_Easting_OSGR       207208.0  448665.386978   91437.509816
# Location_Northing_OSGR      207208.0  297876.160472  155523.641873
# Longitude                   207208.0      -1.306153       1.341705
# Latitude                    207208.0      52.568838       1.401506
# Police_Force                207208.0      22.602781      24.809290
# Accident_Severity           207208.0       2.836908       0.397345
# Number_of_Vehicles          207208.0       1.818781       0.692304
# Number_of_Casualties        207208.0       1.328076       0.785311
# Day_of_Week                 207208.0       4.113123       1.915418
# Local_Authority_(District)  207208.0     264.855614     257.093383
# 1st_Road_Class              207208.0       4.036514       1.388710
# 1st_Road_Number             207208.0     973.528836    1777.105509
# Speed_limit                 207208.0      37.195186      13.141913
# ...

# %%
df.isnull().sum()
# Out:
# Accident_Index                                      0
# Location_Easting_OSGR                               0
# Location_Northing_OSGR                              0
# Longitude                                           0
# Latitude                                            0
# Police_Force                                        0
# Accident_Severity                                   0
# Number_of_Vehicles                                  0
# Number_of_Casualties                                0
# Date                                                0
# Day_of_Week                                         0
# Time                                                5
# Local_Authority_(District)                          0
# Local_Authority_(Highway)                           0
# 1st_Road_Class                                      0
# 1st_Road_Number                                     0
# Road_Type                                           0
# ...

# %%
print(df["Accident_Index"].unique())
print(df["Accident_Index"].value_counts())
# Out:
# ['201201BS70001' '201201BS70002' '201201BS70003' ... '201304FA13134'
#  '201304FA13135' '201304FA13136']
# Accident_Index
# 2.01E+12         67719
# 201206Q057515        2
# 201204AM12178        2
# 201204AM12172        2
# 201204AM12173        2
#                  ...
# 201231B110812        1
# 201231B109312        1
# 201231B108712        1
# 201231B108612        1
# 201304FA13136        1
# Name: count, Length: 116407, dtype: int64

# %%
df2= df.loc[:,["Accident_Severity","Number_of_Casualties","Day_of_Week","Date","Time","Local_Authority_(District)"
                         ,"Local_Authority_(Highway)","Road_Type","Speed_limit","Light_Conditions","Weather_Conditions",
                        "Road_Surface_Conditions","Year"]]
df.head()
# Out:
#   Accident_Index  Location_Easting_OSGR  Location_Northing_OSGR  Longitude  \
# 0  201201BS70001                 527200                  178760  -0.169101
# 1  201201BS70002                 524930                  181430  -0.200838
# 2  201201BS70003                 525860                  178080  -0.188636
# 3  201201BS70004                 524980                  181030  -0.200259
# 4  201201BS70005                 526170                  179200  -0.183773
#
#     Latitude  Police_Force  Accident_Severity  Number_of_Vehicles  \
# 0  51.493429             1                  3                   2
# 1  51.517931             1                  3                   2
# 2  51.487618             1                  3                   2
# 3  51.514325             1                  3                   1
# 4  51.497614             1                  3                   1
#
#    Number_of_Casualties        Date  ...  \
# 0                     1  19/01/2012  ...
# ...

# %%
df2.isnull().sum()
# Out:
# Accident_Severity               0
# Number_of_Casualties            0
# Day_of_Week                     0
# Date                            0
# Time                            5
# Local_Authority_(District)      0
# Local_Authority_(Highway)       0
# Road_Type                       0
# Speed_limit                     0
# Light_Conditions                0
# Weather_Conditions              0
# Road_Surface_Conditions       284
# Year                            1
# dtype: int64

# %%
df2 = df2.dropna()
df2.isnull().sum()
# Out:
# Accident_Severity             0
# Number_of_Casualties          0
# Day_of_Week                   0
# Date                          0
# Time                          0
# Local_Authority_(District)    0
# Local_Authority_(Highway)     0
# Road_Type                     0
# Speed_limit                   0
# Light_Conditions              0
# Weather_Conditions            0
# Road_Surface_Conditions       0
# Year                          0
# dtype: int64

# %%
df2.Year = df2.Year.astype(str)
accidentNumber = df2.groupby("Year") #iki yıl içinde grupladık
sum_accidentNumber=pd.DataFrame(accidentNumber.size().sort_values(ascending=False),columns=["veri sayısı"])
sum_accidentNumber.head()
# Out:
#         veri sayısı
# Year
# 2012.0       179436
# 2013.0        27482

# %%
sns.barplot(y = sum_accidentNumber["veri sayısı"] , x = sum_accidentNumber.index)
plt.title("Yıllara göre kaza sayısı")
# Out:
# Text(0.5, 1.0, 'Yıllara göre kaza sayısı')

# %%
df.Speed_limit = df.Speed_limit.astype(str)
limit_veri_sayi = df.groupby("Speed_limit")
toplam = pd.DataFrame(limit_veri_sayi.size().sort_values(ascending=False),columns=["toplam kaza"])
sns.barplot(y = toplam["toplam kaza"] , x = toplam.index)
plt.title("Hız Limitine göre Kaza sayısı")
# Out:
# Text(0.5, 1.0, 'Hız Limitine göre Kaza sayısı')

# %%
df.Road_Type = df.Road_Type.astype(str)
tip_veri_sayi = df.groupby("Road_Type")
toplam = pd.DataFrame(tip_veri_sayi.size().sort_values(ascending=False),columns=["toplam kaza"])
sns.barplot(x = toplam["toplam kaza"] , y = toplam.index)
plt.title("Yol Tipine göre Kaza sayısı")
# Out:
# Text(0.5, 1.0, 'Yol Tipine göre Kaza sayısı')

# %%
df.Day_of_Week = df.Day_of_Week.astype(str)
gun_veri_sayi = df.groupby("Day_of_Week")
toplam = pd.DataFrame(gun_veri_sayi.size().sort_values(ascending=False),columns=["toplam kaza"])
sns.barplot(x = toplam["toplam kaza"] , y = toplam.index)
plt.title("Haftanın günlerine göre Kaza sayısı")
# Out:
# Text(0.5, 1.0, 'Haftanın günlerine göre Kaza sayısı')

# %%
# yaralı sayısı ile kaza şiddeti karşılaştırması
#sns.lmplot(x='Accident_Severity', y='Number_of_Casualties', data=df)
plt.bar(df['Accident_Severity'],df['Number_of_Casualties'])
# Out:
# <BarContainer object of 207208 artists>
